# %%
import pandas as pd
import numpy as np
import gensim
import gzip
import nltk
from gensim.models import Word2Vec
from nltk import word_tokenize

from nltk.corpus import stopwords

# %%
data=pd.read_json("http://snap.stanford.edu/data/amazon/productGraph/categoryFiles/reviews_Office_Products_5.json.gz",lines=True)

# %%
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
nltk.download('punkt')
nltk.download('stopwords')
stop_words=set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~''' #Function to remove punctuations
def punct_remover(str):
  no_punct = ""
  for char in str:
    if char not in punctuations:
      no_punct = no_punct + char
  return no_punct

# %%
def stopwords_remover(text): #Tokenizing text and removing the stop words
  text=text.lower()
  tokens=word_tokenize(text)
  nostop=[words for words in tokens if not words in stop_words]
  return nostop

# %%
data['reviewText']=data['reviewText'].apply(punct_remover)

# %%
data['revtxt_nostop_tokens']=data['reviewText'].apply(stopwords_remover)

# %%
def unique_tokens(text):
  unique_list=[]
  for words in text:
    if words not in unique_list:
      unique_list.append(words)
  return unique_list

# %%
data['revtxt_unique_tokens']=data['revtxt_nostop_tokens'].apply(unique_tokens)

# %%
data.head()
# Out:
#        reviewerID  ...                               revtxt_unique_tokens
# 0  A32T2H8150OJLU  ...  [bought, first, hp12c, 1984, served, faithfull...
# 1  A3MAFS04ZABRGO  ...  [belated, review, feel, obliged, share, views,...
# 2  A1F1A0QQP2XVH5  ...  [hp, 48gx, kicking, twenty, years, 11, 25, old...
# 3   A49R5DBXXQDE5  ...  [ive, started, finance, stuff, recently, went,...
# 4  A2XRMQA6PJ5ZJ8  ...  [simple, calculations, discounted, cash, flows...
#
# [5 rows x 11 columns]

# %%
wordlist=[[word] for word in data['revtxt_nostop_tokens'][0]]

# %%
wordlist
# Out:
# [['bought'],
#  ['first'],
#  ['hp12c'],
#  ['1984'],
#  ['served'],
#  ['faithfully'],
#  ['2002'],
#  ['lost'],
#  ['travelling'],
#  ['searched'],
#  ['another'],
#  ['one'],
#  ['replace'],
#  ['found'],
#  ['one'],
#  ['difficult'],
#  ['come'],
#  ['area'],
#  ['decided'],
#  ['buy'],
#  ['purchased'],
#  ['hp'],
#  ['49g'],
#  ['mistake'],
#  ['know'],
#  ['many'],
#  ['people'],
#  ['view'],
#  ['hp'],
#  ['49g'],
#  ['49g+'],
#  ['flagship'],
#  ['hp'],
#  ['line'],
#  ['disasterthe'],
#  ['49g'],
#  ['may'],
#  ['powerful'],
#  ['using'],
#  ['extremely'],
#  ['counterintuitiveand'],
#  ['manual'],
#  ['sketchy'],
#  ['best'],
#  ['12c'],
#  ['hand'],
#  ['need'],
#  ['way'],
#  ['makes'],
#  ['good'],
#  ['sense'],
#  ['meif'],
#  ['looking'],
#  ['solid'],
#  ['reliable'],
#  ['calculator'],
#  ['hp12c'],
#  ['may'],
#  ['programmable'],
#  ['basic'],
#  ['statistics'],
#  ['well'],
#  ['many'],
#  ['business'],
#  ['applications'],
#  ['manual'],
#  ['makes'],
#  ['sense'],
#  ['running'],
#  ['short'],
#  ['orderim'],
#  ['ready'],
#  ['set'],
#  ['49g'],
#  ['aside'],
#  ['move'],
#  ['back'],
#  ['old'],
#  ['friend'],
#  ['didnt'],
#  ['even'],
#  ['replace'],
#  ['batteries'],
#  ['well'],
#  ['decade'],
#  ['usehp'],
#  ['12c'],
#  ['im'],
#  ['coming'],
#  ['home']]

# %%
model=Word2Vec(wordlist, size=100, window=5, min_count=1, workers=4)

# %%
for i in wordlist:
  for j in wordlist:
    if j>i:
      print(i[0],' :',j[0],model.similarity(i[0],j[0]))
    else:
      continue
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# bought  : first -0.08953801
# bought  : hp12c 0.0029809186
# bought  : served 0.029079424
# bought  : faithfully -0.0043427115
# bought  : lost 0.08604285
# bought  : travelling 0.08681069
# bought  : searched 0.14456572
# bought  : one -0.061769888
# bought  : replace -0.05378989
# bought  : found 0.015738916
# bought  : one -0.061769888
# bought  : difficult -0.12747951
# bought  : come 0.041012198
# bought  : decided -0.046785183
# bought  : buy 0.061616
# bought  : purchased 0.02775383
# bought  : hp -0.08903679
# bought  : mistake 0.035879534
# bought  : know 0.0191126
# bought  : many -0.06832804
# bought  : people 0.04149545
# bought  : view 0.047386847
# bought  : hp -0.08903679
# bought  : flagship 0.09942631
# bought  : hp -0.08903679
# bought  : line -0.03958247
# bought  : disasterthe 0.074320816
# bought  : may 0.018136084
# bought  : powerful -0.07871128
# bought  : using 0.063232765
# bought  : extremely -0.016324855
# bought  : counterintuitiveand 0.015604312
# bought  : manual -0.057861943
# bought  : sketchy -0.013792893
# bought  : hand -0.09566859
# bought  : need -0.0051838
# bought  : way -0.001430925
# bought  : makes -0.20005895
# bought  : good 0.13276203
# bought  : sense -0.13124031
# bought  : meif -0.19178054
# bought  : looking 0.08371966
# bought  : solid -0.014804176
# bought  : reliable 0.11786259
# bought  : calculator 0.016686684
# bought  : hp12c 0.0029809186
# bought  : may 0.018136084
# bought  : programmable -0.034203913
# bought  : statistics 0.03621981
# bought  : well -0.19742087
# bought  : many -0.06832804
# bought  : business -0.1498246
# bought  : manual -0.057861943
# bought  : makes -0.20005895
# bought  : sense -0.13124031
# bought  : running -0.083703145
# bought  : short -0.075334
# bought  : orderim -0.01901449
# bought  : ready 0.0022397258
# bought  : set 0.033679537
# bought  : move -0.15459578
# bought  : old -0.00058254786
# bought  : friend -0.22188325
# bought  : didnt -0.12718767
# bought  : even -0.039190736
# bought  : replace -0.05378989
# bought  : well -0.19742087
# bought  : decade 0.102725655
# bought  : usehp -0.27854046
# bought  : im -0.06406115
# bought  : coming -0.03365651
# bought  : home 0.048556138
# first  : hp12c 0.027384384
# first  : served -0.11721726
# first  : lost 0.006011861
# first  : travelling -0.11525191
# first  : searched 0.021228723
# first  : one 0.0531698
# first  : replace -0.07975137
# first  : found 0.07900216
# first  : one 0.0531698
# first  : purchased 0.20040894
# first  : hp -0.027882949
# first  : mistake -0.089768276
# first  : know 0.03814921
# first  : many 0.10238733
# first  : people -0.11017588
# first  : view -0.0376719
# first  : hp -0.027882949
# first  : flagship 0.0062403744
# first  : hp -0.027882949
# first  : line -0.04421528
# first  : may -0.19756599
# first  : powerful -0.07546347
# first  : using 0.009977255
# first  : manual 0.09731024
# first  : sketchy 0.0050822967
# first  : hand -0.003958609
# first  : need 0.14716066
# first  : way 0.15596798
# first  : makes 0.067497924
# first  : good -0.09802626
# first  : sense -0.041196153
# first  : meif 0.14019224
# first  : looking 0.08650106
# first  : solid -0.048726737
# first  : reliable -0.013034373
# first  : hp12c 0.027384384
# first  : may -0.19756599
# first  : programmable -0.107209824
# first  : statistics 0.13505375
# first  : well -0.04749515
# first  : many 0.10238733
# first  : manual 0.09731024
# first  : makes 0.067497924
# first  : sense -0.041196153
# first  : running 0.017968895
# first  : short -0.15326986
# first  : orderim 0.21210618
# first  : ready 0.05916604
# first  : set 0.18208218
# first  : move 0.041314077
# first  : old 0.0063768267
# first  : friend 0.12869821
# first  : replace -0.07975137
# first  : well -0.04749515
# first  : usehp 0.07799558
# first  : im 0.04467696
# first  : home 0.16129453
# hp12c  : served 0.038649127
# hp12c  : lost -0.14976987
# hp12c  : travelling 0.07827109
# hp12c  : searched 0.1310701
# hp12c  : one -0.060910765
# hp12c  : replace 0.04878955
# hp12c  : one -0.060910765
# hp12c  : purchased 0.035343315
# hp12c  : mistake 0.09329189
# hp12c  : know 0.15601857
# hp12c  : many -0.23856123
# hp12c  : people -0.049583126
# hp12c  : view 0.13169737
# hp12c  : line -0.13215458
# hp12c  : may -0.04867911
# hp12c  : powerful -0.054290496
# hp12c  : using -0.20745039
# hp12c  : manual 0.018415295
# hp12c  : sketchy 0.16286868
# hp12c  : need -0.030554326
# hp12c  : way 0.03716508
# hp12c  : makes -0.07138465
# hp12c  : sense 0.08423441
# hp12c  : meif -0.007081242
# hp12c  : looking -0.042079825
# hp12c  : solid -0.028984051
# hp12c  : reliable -0.051784527
# hp12c  : may -0.04867911
# hp12c  : programmable -0.07112085
# hp12c  : statistics 0.052001126
# hp12c  : well -0.07825939
# hp12c  : many -0.23856123
# hp12c  : manual 0.018415295
# hp12c  : makes -0.07138465
# hp12c  : sense 0.08423441
# hp12c  : running -0.0033144017
# hp12c  : short -0.07169636
# hp12c  : orderim 0.099499024
# hp12c  : ready 0.026162311
# hp12c  : set 0.08219603
# hp12c  : move -0.2719536
# hp12c  : old 0.17818221
# hp12c  : replace 0.04878955
# hp12c  : well -0.07825939
# hp12c  : usehp -0.033479933
# hp12c  : im 0.02318353
# 1984  : bought -0.10088945
# 1984  : first 0.007984007
# 1984  : hp12c -0.07434865
# 1984  : served 0.12614495
# 1984  : faithfully 0.0061454065
# 1984  : 2002 0.13455413
# 1984  : lost 0.039237093
# 1984  : travelling 0.03845928
# 1984  : searched -0.045018245
# 1984  : another -0.12541805
# 1984  : one -0.121239185
# 1984  : replace -0.17088972
# 1984  : found 0.09047297
# 1984  : one -0.121239185
# 1984  : difficult 0.0320787
# 1984  : come 0.054280784
# 1984  : area -0.13064131
# 1984  : decided -0.00037575932
# 1984  : buy -0.04139526
# 1984  : purchased 0.042254183
# 1984  : hp 0.09914076
# 1984  : 49g 0.12622017
# 1984  : mistake 0.039719902
# 1984  : know 0.04229201
# 1984  : many -0.06469368
# 1984  : people -0.09380703
# 1984  : view 0.009998135
# 1984  : hp 0.09914076
# 1984  : 49g 0.12622017
# 1984  : 49g+ 0.08446152
# 1984  : flagship -0.1072514
# 1984  : hp 0.09914076
# 1984  : line 0.13284898
# 1984  : disasterthe 0.18332563
# 1984  : 49g 0.12622017
# 1984  : may -0.14332509
# 1984  : powerful 0.19078511
# 1984  : using -0.14510173
# 1984  : extremely 0.05516938
# 1984  : counterintuitiveand 0.061253455
# 1984  : manual 0.07646834
# 1984  : sketchy 0.020060873
# 1984  : best -0.081773385
# 1984  : hand -0.17942686
# 1984  : need -0.07316499
# 1984  : way -0.028013963
# 1984  : makes 0.09041934
# 1984  : good -0.008199203
# 1984  : sense -0.103078745
# 1984  : meif 0.051475305
# 1984  : looking -0.0747262
# 1984  : solid 0.0665074
# 1984  : reliable -0.16467345
# 1984  : calculator 0.08087914
# 1984  : hp12c -0.07434865
# 1984  : may -0.14332509
# 1984  : programmable 0.002099866
# 1984  : basic 0.04399686
# 1984  : statistics 0.017610386
# 1984  : well -0.019297361
# 1984  : many -0.06469368
# 1984  : business 0.07382135
# 1984  : applications 0.100531764
# 1984  : manual 0.07646834
# 1984  : makes 0.09041934
# 1984  : sense -0.103078745
# 1984  : running 0.048518535
# 1984  : short 0.05250816
# 1984  : orderim 0.09792894
# 1984  : ready -0.016133104
# 1984  : set -0.072593115
# 1984  : 49g 0.12622017
# 1984  : aside 0.09034343
# 1984  : move 0.1207599
# 1984  : back -0.04676137
# 1984  : old 0.03838164
# 1984  : friend 0.104913324
# 1984  : didnt -0.05880465
# 1984  : even -0.010116891
# 1984  : replace -0.17088972
# 1984  : batteries 0.12449095
# 1984  : well -0.019297361
# 1984  : decade 0.037300512
# 1984  : usehp 0.02765963
# 1984  : im 0.11745276
# 1984  : coming 0.16366093
# 1984  : home -0.02872863
# served  : travelling 0.07067241
# served  : view 0.12157435
# served  : using 0.045098487
# served  : sketchy -0.037667908
# served  : way -0.06610677
# served  : solid 0.06295639
# served  : statistics 0.02497883
# served  : well 0.052575536
# served  : short 0.020833792
# served  : set 0.043725852
# served  : well 0.052575536
# served  : usehp -0.014199722
# faithfully  : first -0.10231086
# faithfully  : hp12c 0.033521086
# faithfully  : served -0.04069323
# faithfully  : lost -0.14520986
# faithfully  : travelling 0.06521681
# faithfully  : searched 0.054855376
# faithfully  : one 0.20537937
# faithfully  : replace 0.03814919
# faithfully  : found 0.099511415
# faithfully  : one 0.20537937
# faithfully  : purchased 0.1453099
# faithfully  : hp -0.08655447
# faithfully  : mistake 0.079274945
# faithfully  : know 0.016477313
# faithfully  : many 0.024481284
# faithfully  : people 0.11707008
# faithfully  : view 0.15983568
# faithfully  : hp -0.08655447
# faithfully  : flagship -0.045349613
# faithfully  : hp -0.08655447
# faithfully  : line 0.041474734
# faithfully  : may -0.122096114
# faithfully  : powerful -0.043967415
# faithfully  : using 0.020378197
# faithfully  : manual -0.14689401
# faithfully  : sketchy 0.06828346
# faithfully  : hand 0.117395766
# faithfully  : need -0.1905934
# faithfully  : way -0.054085914
# faithfully  : makes -0.06824683
# faithfully  : good 0.06638279
# faithfully  : sense -0.1838654
# faithfully  : meif 0.045909546
# faithfully  : looking 0.0781524
# faithfully  : solid -0.23314904
# faithfully  : reliable 0.039361324
# faithfully  : hp12c 0.033521086
# faithfully  : may -0.122096114
# faithfully  : programmable 0.03961269
# faithfully  : statistics -0.045190956
# faithfully  : well -0.17240857
# faithfully  : many 0.024481284
# faithfully  : manual -0.14689401
# faithfully  : makes -0.06824683
# faithfully  : sense -0.1838654
# faithfully  : running 0.0368597
# faithfully  : short -0.014774597
# faithfully  : orderim -0.011357249
# faithfully  : ready -0.112296864
# faithfully  : set -0.056453485
# faithfully  : move -0.072453104
# faithfully  : old 0.15934974
# faithfully  : friend -0.13882595
# faithfully  : replace 0.03814919
# faithfully  : well -0.17240857
# faithfully  : usehp 0.070834175
# faithfully  : im -0.24365845
# faithfully  : home 0.09971897
# 2002  : bought -0.16433416
# 2002  : first 0.14877513
# 2002  : hp12c -0.13642743
# 2002  : served 0.19621006
# 2002  : faithfully -0.050306533
# 2002  : lost 0.019381057
# 2002  : travelling 0.028689446
# 2002  : searched -0.03160717
# 2002  : another -0.048362616
# 2002  : one 0.042537715
# 2002  : replace -0.04487951
# 2002  : found 0.069021106
# 2002  : one 0.042537715
# 2002  : difficult -0.05795663
# 2002  : come 0.013779424
# 2002  : area 0.083213344
# 2002  : decided -0.124530055
# 2002  : buy -0.07853961
# 2002  : purchased 0.16995521
# 2002  : hp 0.11366645
# 2002  : 49g -0.054208938
# 2002  : mistake 0.07096795
# 2002  : know -0.045285318
# 2002  : many 0.0784566
# 2002  : people -0.14936857
# 2002  : view -0.06679177
# 2002  : hp 0.11366645
# 2002  : 49g -0.054208938
# 2002  : 49g+ 0.10941635
# 2002  : flagship -0.090756424
# 2002  : hp 0.11366645
# 2002  : line 0.032837138
# 2002  : disasterthe -0.07330785
# 2002  : 49g -0.054208938
# 2002  : may 0.03268907
# 2002  : powerful 0.01571203
# 2002  : using -0.01867078
# 2002  : extremely 0.09454409
# 2002  : counterintuitiveand 0.15118083
# 2002  : manual -0.06525878
# 2002  : sketchy -0.020310981
# 2002  : best 0.019829454
# 2002  : hand -0.17439511
# 2002  : need 0.25825018
# 2002  : way -0.033171296
# 2002  : makes 0.11591396
# 2002  : good -0.04848303
# 2002  : sense 0.0825329
# 2002  : meif 0.10540973
# 2002  : looking -0.1962081
# 2002  : solid -0.0036168492
# 2002  : reliable -0.09211056
# 2002  : calculator -0.040190138
# 2002  : hp12c -0.13642743
# 2002  : may 0.03268907
# 2002  : programmable 0.19545017
# 2002  : basic 0.13347891
# 2002  : statistics -0.010784934
# 2002  : well -0.1521468
# 2002  : many 0.0784566
# 2002  : business 0.20757042
# 2002  : applications -0.026979605
# 2002  : manual -0.06525878
# 2002  : makes 0.11591396
# 2002  : sense 0.0825329
# 2002  : running 0.0051929033
# 2002  : short -0.038702443
# 2002  : orderim -0.007298666
# 2002  : ready 0.053302206
# 2002  : set 0.07795757
# 2002  : 49g -0.054208938
# 2002  : aside -0.17202203
# 2002  : move 0.14621063
# 2002  : back 0.06848856
# 2002  : old -0.15055084
# 2002  : friend 0.06074406
# 2002  : didnt -0.036922745
# 2002  : even -0.08806139
# 2002  : replace -0.04487951
# 2002  : batteries 0.11692258
# 2002  : well -0.1521468
# 2002  : decade -0.20461017
# 2002  : usehp -0.043585744
# 2002  : im -0.14524704
# 2002  : coming 0.18227364
# 2002  : home 0.17687559
# lost  : served 0.10501003
# lost  : travelling -0.09109034
# lost  : searched -0.122954
# lost  : one -0.07768584
# lost  : replace -0.114345476
# lost  : one -0.07768584
# lost  : purchased 0.087064385
# lost  : mistake -0.14048938
# lost  : many 0.10280813
# lost  : people -0.07862346
# lost  : view -0.09977497
# lost  : may 0.014830226
# lost  : powerful 0.16414571
# lost  : using -0.027311878
# lost  : manual -0.10868596
# lost  : sketchy 0.16475514
# lost  : need 0.20181748
# lost  : way 0.08081451
# lost  : makes -0.18460345
# lost  : sense 0.0147497505
# lost  : meif -0.029329952
# lost  : solid 0.034190923
# lost  : reliable -0.08189656
# lost  : may 0.014830226
# lost  : programmable -0.00118887
# lost  : statistics -0.035940517
# lost  : well 0.10705128
# lost  : many 0.10280813
# lost  : manual -0.10868596
# lost  : makes -0.18460345
# lost  : sense 0.0147497505
# lost  : running -0.1002372
# lost  : short -0.048206087
# lost  : orderim 0.023911092
# lost  : ready 0.1270279
# lost  : set -0.13931657
# lost  : move 0.12985991
# lost  : old -0.040841524
# lost  : replace -0.114345476
# lost  : well 0.10705128
# lost  : usehp 0.016871039
# travelling  : view 0.112128876
# travelling  : using 0.19053674
# travelling  : way 0.046314746
# travelling  : well -0.23073354
# travelling  : well -0.23073354
# travelling  : usehp -0.12746021
# searched  : served -0.021387275
# searched  : travelling -0.005813284
# searched  : view 0.24567917
# searched  : using 0.034641013
# searched  : sketchy -0.09665721
# searched  : way 0.13733076
# searched  : sense -0.14952603
# searched  : solid 0.04870266
# searched  : statistics 0.18507962
# searched  : well -0.111052215
# searched  : sense -0.14952603
# searched  : short -0.01143097
# searched  : set 0.02591109
# searched  : well -0.111052215
# searched  : usehp 0.03982025
# another  : bought -0.18661927
# another  : first 0.100529335
# another  : hp12c 0.12672243
# another  : served -0.04016899
# another  : faithfully -0.051008653
# another  : lost -0.25979072
# another  : travelling 0.030051975
# another  : searched 0.06503702
# another  : one 0.053302024
# another  : replace 0.1711747
# another  : found 0.014586436
# another  : one 0.053302024
# another  : difficult 0.017171003
# another  : come -0.13950196
# another  : area 0.14783992
# another  : decided 0.18605503
# another  : buy 0.058992136
# another  : purchased -0.27759865
# another  : hp 0.09192923
# another  : mistake 0.028943025
# another  : know 0.10201938
# another  : many -0.2336686
# another  : people -0.05353418
# another  : view 0.05081099
# another  : hp 0.09192923
# another  : flagship 0.19640464
# another  : hp 0.09192923
# another  : line 0.0072139287
# another  : disasterthe 0.054722734
# another  : may -0.057726886
# another  : powerful -0.15885141
# another  : using -0.021744546
# another  : extremely -0.05372911
# another  : counterintuitiveand -0.1343152
# another  : manual 0.1234878
# another  : sketchy 0.026524771
# another  : best 0.049090046
# another  : hand 0.076529615
# another  : need -0.20032683
# another  : way 0.14330931
# another  : makes 0.18529896
# another  : good 0.09159563
# another  : sense 0.080640845
# another  : meif 0.06245742
# another  : looking -0.09879189
# another  : solid 0.0013638207
# another  : reliable 0.00046611193
# another  : calculator -0.2383474
# another  : hp12c 0.12672243
# another  : may -0.057726886
# another  : programmable -0.16246647
# another  : basic 0.111704044
# another  : statistics 0.17467177
# another  : well -0.19843058
# another  : many -0.2336686
# another  : business -0.12957275
# another  : applications 0.033880934
# another  : manual 0.1234878
# another  : makes 0.18529896
# another  : sense 0.080640845
# another  : running -0.07222866
# another  : short 0.19671287
# another  : orderim -0.08099329
# another  : ready -0.07982623
# another  : set -0.06415997
# another  : aside -0.019613175
# another  : move -0.057871237
# another  : back -0.037128795
# another  : old -0.05597272
# another  : friend -0.047254875
# another  : didnt 0.033566196
# another  : even -0.035967734
# another  : replace 0.1711747
# another  : batteries -0.0043269563
# another  : well -0.19843058
# another  : decade -0.008263793
# another  : usehp 0.1826912
# another  : im -0.095238075
# another  : coming -0.23259287
# another  : home 0.17334203
# one  : served 0.0020986744
# one  : travelling 0.01602929
# one  : searched -0.107249476
# one  : replace 0.1852536
# one  : purchased -0.116727844
# one  : people -0.085843004
# one  : view -0.020958198
# one  : powerful -0.045873646
# one  : using 0.055788413
# one  : sketchy -0.0069032754
# one  : way -0.14452298
# one  : sense -0.006306413
# one  : solid 0.0875631
# one  : reliable -0.09348783
# one  : programmable -0.07284575
# one  : statistics 0.10581571
# one  : well -0.018578561
# one  : sense -0.006306413
# one  : running 0.09524966
# one  : short 0.07301618
# one  : orderim -0.009159389
# one  : ready 0.07787111
# one  : set 0.18222009
# one  : replace 0.1852536
# one  : well -0.018578561
# one  : usehp 0.24452752
# replace  : served -0.0136855515
# replace  : travelling 0.21775621
# replace  : searched 0.055327628
# replace  : view -0.0894385
# replace  : using 0.09662213
# replace  : sketchy -0.0628247
# replace  : way -0.20368303
# replace  : sense -0.090631604
# replace  : solid 0.17549258
# replace  : statistics 0.16097426
# replace  : well 0.053403795
# replace  : sense -0.090631604
# replace  : running -0.11655331
# replace  : short 0.071116224
# replace  : set 0.053629965
# replace  : well 0.053403795
# replace  : usehp 0.20741606
# found  : hp12c 0.07332309
# found  : served 0.019985637
# found  : lost -0.03907797
# found  : travelling 0.034107197
# found  : searched 0.02261217
# found  : one -0.05398675
# found  : replace 0.050522976
# found  : one -0.05398675
# found  : purchased -0.18332298
# found  : hp 0.06598391
# found  : mistake 0.13727555
# found  : know -0.084305875
# found  : many 0.014610741
# found  : people -0.05894658
# found  : view 0.06886718
# found  : hp 0.06598391
# found  : hp 0.06598391
# found  : line -0.11951425
# found  : may -0.11942474
# found  : powerful 0.052095227
# found  : using 0.08989157
# found  : manual 0.05489805
# found  : sketchy -0.14801306
# found  : hand -0.025918875
# found  : need -0.006820407
# found  : way -0.041912463
# found  : makes 0.01631709
# found  : good 0.07956899
# found  : sense 0.0026457703
# found  : meif 0.11553193
# found  : looking -0.03540792
# found  : solid 0.1958915
# found  : reliable 0.101781465
# found  : hp12c 0.07332309
# found  : may -0.11942474
# found  : programmable -0.15958324
# found  : statistics 0.08290403
# found  : well -0.11619469
# found  : many 0.014610741
# found  : manual 0.05489805
# found  : makes 0.01631709
# found  : sense 0.0026457703
# found  : running 0.08144451
# found  : short -0.011287586
# found  : orderim -0.09586698
# found  : ready 0.11221732
# found  : set 0.04251924
# found  : move -0.16951273
# found  : old -0.07612473
# found  : friend 0.061863374
# found  : replace 0.050522976
# found  : well -0.11619469
# found  : usehp 0.014882566
# found  : im -0.18370469
# found  : home -0.083327875
# one  : served 0.0020986744
# one  : travelling 0.01602929
# one  : searched -0.107249476
# one  : replace 0.1852536
# one  : purchased -0.116727844
# one  : people -0.085843004
# one  : view -0.020958198
# one  : powerful -0.045873646
# one  : using 0.055788413
# one  : sketchy -0.0069032754
# one  : way -0.14452298
# one  : sense -0.006306413
# one  : solid 0.0875631
# one  : reliable -0.09348783
# one  : programmable -0.07284575
# one  : statistics 0.10581571
# one  : well -0.018578561
# one  : sense -0.006306413
# one  : running 0.09524966
# one  : short 0.07301618
# one  : orderim -0.009159389
# one  : ready 0.07787111
# one  : set 0.18222009
# one  : replace 0.1852536
# one  : well -0.018578561
# one  : usehp 0.24452752
# difficult  : first 0.037814315
# difficult  : hp12c -0.07362624
# difficult  : served -0.043178234
# difficult  : faithfully -0.21106282
# difficult  : lost 0.17643395
# difficult  : travelling 0.097110055
# difficult  : searched -0.09501299
# difficult  : one -0.1692069
# difficult  : replace 0.17951861
# difficult  : found 0.044542287
# difficult  : one -0.1692069
# difficult  : purchased -0.14647005
# difficult  : hp 0.05982164
# difficult  : mistake -0.019674852
# difficult  : know 0.00687875
# difficult  : many 0.034538623
# difficult  : people 0.010392123
# difficult  : view -0.045087066
# difficult  : hp 0.05982164
# difficult  : flagship 0.08131757
# difficult  : hp 0.05982164
# difficult  : line 0.025480043
# difficult  : disasterthe -0.14190719
# difficult  : may 0.10038354
# difficult  : powerful 0.043922093
# difficult  : using -0.046913926
# difficult  : extremely -0.11647326
# difficult  : manual -0.037700366
# difficult  : sketchy -0.033058193
# difficult  : hand -0.057944585
# difficult  : need -0.028056195
# difficult  : way -0.0046081315
# difficult  : makes 0.13297081
# difficult  : good -0.09271258
# difficult  : sense -0.0738447
# difficult  : meif 0.0074256626
# difficult  : looking 0.0010438173
# difficult  : solid 0.18505082
# difficult  : reliable -0.021514853
# difficult  : hp12c -0.07362624
# difficult  : may 0.10038354
# difficult  : programmable -0.0012681406
# difficult  : statistics 0.061585892
# difficult  : well -0.17507644
# difficult  : many 0.034538623
# difficult  : manual -0.037700366
# difficult  : makes 0.13297081
# difficult  : sense -0.0738447
# difficult  : running 0.058909345
# difficult  : short 0.079288095
# difficult  : orderim 0.017745603
# difficult  : ready 0.15028726
# difficult  : set -0.009778997
# difficult  : move -0.21141797
# difficult  : old -0.07164656
# difficult  : friend 0.06134874
# difficult  : even -0.075792894
# difficult  : replace 0.17951861
# difficult  : well -0.17507644
# difficult  : usehp -0.09214328
# difficult  : im 0.10974163
# difficult  : home -0.0221119
# come  : first -0.109867595
# come  : hp12c -0.059050884
# come  : served 0.0108807
# come  : faithfully 0.0022917027
# come  : lost 0.025262618
# come  : travelling -0.012734705
# come  : searched -0.04691576
# come  : one 0.090110146
# come  : replace 0.2140541
# come  : found -0.016798886
# come  : one 0.090110146
# come  : difficult -0.0966582
# come  : decided -0.112402506
# come  : purchased 0.008909639
# come  : hp 0.18367676
# come  : mistake -0.04852514
# come  : know -0.059319526
# come  : many -0.08990218
# come  : people -0.099846706
# come  : view -0.12716283
# come  : hp 0.18367676
# come  : flagship 0.040728487
# come  : hp 0.18367676
# come  : line 0.16712709
# come  : disasterthe -0.0007358822
# come  : may 0.042210605
# come  : powerful 0.01732694
# come  : using -0.11421478
# come  : extremely 0.012513373
# come  : counterintuitiveand 0.17936786
# come  : manual -0.15549171
# come  : sketchy 0.0065977303
# come  : hand -0.17179793
# come  : need 0.033324648
# come  : way -0.13071404
# come  : makes 0.04570795
# come  : good 0.049301025
# come  : sense 0.022574501
# come  : meif -0.073113166
# come  : looking 0.06642097
# come  : solid -0.009482698
# come  : reliable 0.06300861
# come  : hp12c -0.059050884
# come  : may 0.042210605
# come  : programmable 0.19928497
# come  : statistics 0.044725284
# come  : well 0.12472143
# come  : many -0.08990218
# come  : manual -0.15549171
# come  : makes 0.04570795
# come  : sense 0.022574501
# come  : running 0.036793254
# come  : short 0.09078169
# come  : orderim 0.013646431
# come  : ready 0.018174494
# come  : set 0.107398845
# come  : move 0.053032883
# come  : old -0.19547507
# come  : friend -0.20980296
# come  : didnt 0.0051432024
# come  : even 0.042865507
# come  : replace 0.2140541
# come  : well 0.12472143
# come  : decade 0.110090986
# come  : usehp 0.10900336
# come  : im -0.14901616
# come  : coming 0.07354751
# come  : home 0.044389706
# area  : bought 0.0073997485
# area  : first -0.012747573
# area  : hp12c -0.12137372
# area  : served 0.21722418
# area  : faithfully -0.02653247
# area  : lost 0.08191702
# area  : travelling 0.115827896
# area  : searched -0.16423486
# area  : one -0.019177964
# area  : replace -0.16846998
# area  : found 0.0432243
# area  : one -0.019177964
# area  : difficult -0.027402356
# area  : come -0.11665749
# area  : decided -0.04049857
# area  : buy -0.021847941
# area  : purchased -0.11649786
# area  : hp -0.022086777
# area  : mistake 0.1880671
# area  : know -0.0217119
# area  : many 0.07005101
# area  : people 0.030279886
# area  : view -0.10770698
# area  : hp -0.022086777
# area  : flagship 0.12460643
# area  : hp -0.022086777
# area  : line 0.023743829
# area  : disasterthe -0.060716275
# area  : may 0.15282919
# area  : powerful -0.15818302
# area  : using 0.0816837
# area  : extremely -0.11733664
# area  : counterintuitiveand 0.0425542
# area  : manual 0.007962371
# area  : sketchy -0.08545308
# area  : best 0.11452082
# area  : hand 0.10312804
# area  : need 0.16436343
# area  : way 0.07453777
# area  : makes -0.00066258316
# area  : good -0.0030229937
# area  : sense 0.029090133
# area  : meif 0.13023783
# area  : looking 0.0067001036
# area  : solid -0.14318028
# area  : reliable 0.2062337
# area  : calculator -0.020159297
# area  : hp12c -0.12137372
# area  : may 0.15282919
# area  : programmable -0.06566726
# area  : basic -0.12114702
# area  : statistics -0.07989062
# area  : well -0.10729909
# area  : many 0.07005101
# area  : business -0.14970036
# area  : manual 0.007962371
# area  : makes -0.00066258316
# area  : sense 0.029090133
# area  : running -0.08189096
# area  : short -0.068014845
# area  : orderim 0.103965074
# area  : ready -0.1658792
# area  : set -0.014653381
# area  : aside -0.06711867
# area  : move 0.021437999
# area  : back -0.00066905865
# area  : old -0.08133785
# area  : friend -0.05526497
# area  : didnt -0.06489904
# area  : even 0.008126036
# area  : replace -0.16846998
# area  : batteries 0.0149974935
# area  : well -0.10729909
# area  : decade 0.07302276
# area  : usehp 0.07337378
# area  : im 0.02278779
# area  : coming -0.12190847
# area  : home -0.041878138
# decided  : first -0.005827249
# decided  : hp12c 0.024818175
# decided  : served 0.0090177385
# decided  : faithfully 0.018733118
# decided  : lost 0.083475895
# decided  : travelling 0.14898157
# decided  : searched -0.047858704
# decided  : one 0.15375589
# decided  : replace 0.050269116
# decided  : found -0.138849
# decided  : one 0.15375589
# decided  : difficult 0.033372324
# decided  : purchased -0.16671908
# decided  : hp -0.063853756
# decided  : mistake 0.08686837
# decided  : know -0.104937054
# decided  : many 0.02864384
# decided  : people -0.06269156
# decided  : view -0.10435845
# decided  : hp -0.063853756
# decided  : flagship 0.02162468
# decided  : hp -0.063853756
# decided  : line 0.03865289
# decided  : disasterthe 0.09548223
# decided  : may -0.009440398
# decided  : powerful -0.01511915
# decided  : using -0.0902369
# decided  : extremely 0.04013358
# decided  : manual -0.036502667
# decided  : sketchy -0.025504608
# decided  : hand 0.12762237
# decided  : need -0.091964096
# decided  : way 0.13433707
# decided  : makes 0.08003007
# decided  : good 0.031393874
# decided  : sense 0.020978624
# decided  : meif 0.008938333
# decided  : looking 0.05386541
# decided  : solid -0.03355994
# decided  : reliable 0.019786624
# decided  : hp12c 0.024818175
# decided  : may -0.009440398
# decided  : programmable -0.1714339
# decided  : statistics 0.034262776
# decided  : well -0.03988448
# decided  : many 0.02864384
# decided  : manual -0.036502667
# decided  : makes 0.08003007
# decided  : sense 0.020978624
# decided  : running 0.099040136
# decided  : short 0.073852524
# decided  : orderim -0.19480994
# decided  : ready 0.07401902
# decided  : set 0.0090014655
# decided  : move -0.062434487
# decided  : old -0.059860248
# decided  : friend -0.001792833
# decided  : didnt -0.02998487
# decided  : even -0.008079249
# decided  : replace 0.050269116
# decided  : well -0.03988448
# decided  : usehp 0.09461716
# decided  : im -0.04097665
# decided  : home -0.062098533
# buy  : first 0.0022032685
# buy  : hp12c 0.07775905
# buy  : served -0.099621
# buy  : faithfully -0.13906167
# buy  : lost -0.09331966
# buy  : travelling -0.14437532
# buy  : searched 0.08828225
# buy  : one 0.044014007
# buy  : replace 0.010258884
# buy  : found 0.19364983
# buy  : one 0.044014007
# buy  : difficult 0.0359473
# buy  : come 0.079817794
# buy  : decided -0.06664669
# buy  : purchased -0.32666358
# buy  : hp -0.031503767
# buy  : mistake -0.07435831
# buy  : know -0.05341442
# buy  : many -0.12921222
# buy  : people -0.08071345
# buy  : view -0.025129901
# buy  : hp -0.031503767
# buy  : flagship -0.013513241
# buy  : hp -0.031503767
# buy  : line -0.11298736
# buy  : disasterthe -0.044052586
# buy  : may 0.0017046296
# buy  : powerful -0.13384792
# buy  : using 0.10794696
# buy  : extremely -0.047346022
# buy  : counterintuitiveand 0.016560676
# buy  : manual 0.14727154
# buy  : sketchy -0.018054012
# buy  : hand -0.050007183
# buy  : need 0.008943903
# buy  : way -0.12411416
# buy  : makes 0.066044934
# buy  : good 0.09087557
# buy  : sense -0.20862475
# buy  : meif 0.16988322
# buy  : looking -0.024200121
# buy  : solid 0.069836475
# buy  : reliable -0.11932101
# buy  : calculator 0.07786036
# buy  : hp12c 0.07775905
# buy  : may 0.0017046296
# buy  : programmable 0.13853675
# buy  : statistics 0.13757259
# buy  : well -0.0008634899
# buy  : many -0.12921222
# buy  : manual 0.14727154
# buy  : makes 0.066044934
# buy  : sense -0.20862475
# buy  : running 0.09725678
# buy  : short -0.12968363
# buy  : orderim -0.14295769
# buy  : ready 0.11595881
# buy  : set -0.048207738
# buy  : move -0.08240524
# buy  : old -0.0019138512
# buy  : friend 0.15242872
# buy  : didnt 0.097313754
# buy  : even -0.07407462
# buy  : replace 0.010258884
# buy  : well -0.0008634899
# buy  : decade -0.14169253
# buy  : usehp 0.21364017
# buy  : im 0.026419241
# buy  : coming -0.10015941
# buy  : home 0.07341262
# purchased  : served -0.116422944
# purchased  : travelling -0.005204802
# purchased  : searched 0.035692606
# purchased  : replace -0.13104916
# purchased  : view -0.16000117
# purchased  : using 0.035622157
# purchased  : sketchy -0.04345272
# purchased  : way 0.022034025
# purchased  : sense 0.14769034
# purchased  : solid -0.12484592
# purchased  : reliable -0.08658531
# purchased  : statistics -0.088951424
# purchased  : well 0.04334644
# purchased  : sense 0.14769034
# purchased  : running 0.06517734
# purchased  : short -0.12167996
# purchased  : ready -0.07286843
# purchased  : set 0.1879926
# purchased  : replace -0.13104916
# purchased  : well 0.04334644
# purchased  : usehp -0.12826826
# hp  : hp12c -0.10700917
# hp  : served 0.07317559
# hp  : lost -0.11701512
# hp  : travelling -0.0076341215
# hp  : searched -0.23525049
# hp  : one 0.12941937
# hp  : replace 0.099550016
# hp  : one 0.12941937
# hp  : purchased 0.007682179
# hp  : mistake -0.17537518
# hp  : know 0.073518045
# hp  : many -0.111629225
# hp  : people -0.05704288
# hp  : view -0.0755801
# hp  : line -0.034542456
# hp  : may 0.14208616
# hp  : powerful 0.20568836
# hp  : using -0.1385196
# hp  : manual 0.10488667
# hp  : sketchy -0.021226026
# hp  : need -0.10472019
# hp  : way -0.10633773
# hp  : makes 0.024053058
# hp  : sense -0.05868675
# hp  : meif -0.025837913
# hp  : looking 0.023399206
# hp  : solid 0.04100031
# hp  : reliable -0.036193695
# hp  : hp12c -0.10700917
# hp  : may 0.14208616
# hp  : programmable 0.018359851
# hp  : statistics 0.02343352
# hp  : well -0.13377988
# hp  : many -0.111629225
# hp  : manual 0.10488667
# hp  : makes 0.024053058
# hp  : sense -0.05868675
# hp  : running -0.17155127
# hp  : short 0.18950808
# hp  : orderim 0.12484109
# hp  : ready 0.025622105
# hp  : set -0.1414194
# hp  : move 0.14051762
# hp  : old -0.06276717
# hp  : replace 0.099550016
# hp  : well -0.13377988
# hp  : usehp 0.09521609
# hp  : im -0.16079812
# 49g  : bought -0.06758465
# 49g  : first 0.1554061
# 49g  : hp12c 0.14062624
# 49g  : served 0.011759298
# 49g  : faithfully 0.112470165
# 49g  : lost -0.099636234
# 49g  : travelling 0.003085442
# 49g  : searched 0.22173272
# 49g  : another 0.105357796
# 49g  : one -0.00298943
# 49g  : replace -0.07149416
# 49g  : found 0.07393998
# 49g  : one -0.00298943
# 49g  : difficult -0.122904494
# 49g  : come -0.08041403
# 49g  : area -0.09192875
# 49g  : decided 0.047910288
# 49g  : buy 0.06760444
# 49g  : purchased -0.045623597
# 49g  : hp 0.0523196
# 49g  : mistake -0.032432113
# 49g  : know -0.052212544
# 49g  : many -0.06958547
# 49g  : people 0.02538858
# 49g  : view 0.27605247
# 49g  : hp 0.0523196
# 49g  : 49g+ -0.16550966
# 49g  : flagship -0.037511334
# 49g  : hp 0.0523196
# 49g  : line 0.08297605
# 49g  : disasterthe 0.07725054
# 49g  : may -0.1345508
# 49g  : powerful 0.0041445056
# 49g  : using -0.09805582
# 49g  : extremely 0.03303127
# 49g  : counterintuitiveand 0.09606037
# 49g  : manual 0.06729656
# 49g  : sketchy 0.17243613
# 49g  : best 0.030927125
# 49g  : hand 0.08194016
# 49g  : need 0.20940849
# 49g  : way -0.020776616
# 49g  : makes 0.06942752
# 49g  : good 0.06922048
# 49g  : sense -0.040475823
# 49g  : meif -0.197236
# 49g  : looking 0.0799404
# 49g  : solid -0.060759444
# 49g  : reliable -0.014168556
# 49g  : calculator -0.021669187
# 49g  : hp12c 0.14062624
# 49g  : may -0.1345508
# 49g  : programmable -0.0873708
# 49g  : basic 0.18767066
# 49g  : statistics -0.12864259
# 49g  : well -0.09057644
# 49g  : many -0.06958547
# 49g  : business -0.042117573
# 49g  : applications 0.16189748
# 49g  : manual 0.06729656
# 49g  : makes 0.06942752
# 49g  : sense -0.040475823
# 49g  : running 0.15550025
# 49g  : short 0.15824866
# 49g  : orderim 0.09146529
# 49g  : ready -0.11874571
# 49g  : set -0.025183557
# 49g  : aside 0.095975034
# 49g  : move -0.20131099
# 49g  : back -0.040228736
# 49g  : old 0.037803773
# 49g  : friend -0.15570347
# 49g  : didnt -0.0006688067
# 49g  : even 0.14021145
# 49g  : replace -0.07149416
# 49g  : batteries -0.013590398
# 49g  : well -0.09057644
# 49g  : decade 0.070473574
# 49g  : usehp 0.09178431
# 49g  : im 0.13673343
# 49g  : coming 0.0041993614
# 49g  : home -0.06397448
# mistake  : served 0.09935767
# mistake  : travelling 0.10170386
# mistake  : searched -0.08326984
# mistake  : one -0.1882953
# mistake  : replace 0.02448635
# mistake  : one -0.1882953
# mistake  : purchased -0.14963539
# mistake  : people 0.028267693
# mistake  : view 0.05291014
# mistake  : powerful -0.14802724
# mistake  : using -0.12552334
# mistake  : sketchy -0.020126652
# mistake  : need 0.056027677
# mistake  : way 0.0075617013
# mistake  : sense -0.015757205
# mistake  : solid 0.0020477208
# mistake  : reliable 0.12623835
# mistake  : programmable 0.046166252
# mistake  : statistics -0.19337806
# mistake  : well 0.05029194
# mistake  : sense -0.015757205
# mistake  : running 0.06522712
# mistake  : short -0.14159538
# mistake  : orderim -0.05563096
# mistake  : ready 0.0630406
# mistake  : set 0.06787213
# mistake  : move -0.108465075
# mistake  : old -0.08858428
# mistake  : replace 0.02448635
# mistake  : well 0.05029194
# mistake  : usehp 0.08961968
# know  : served 0.0005106706
# know  : lost 0.048162196
# know  : travelling 0.04645947
# know  : searched -0.019463342
# know  : one -0.014327692
# know  : replace -0.0036183854
# know  : one -0.014327692
# know  : purchased 0.04592219
# know  : mistake -0.14533104
# know  : many -0.111422665
# know  : people 0.0042099645
# know  : view -0.11157382
# know  : line 0.065506674
# know  : may -0.048369702
# know  : powerful 0.03965988
# know  : using 0.12025115
# know  : manual -0.07767054
# know  : sketchy 0.16641499
# know  : need -0.101519376
# know  : way 0.08884343
# know  : makes -0.18480556
# know  : sense -0.08120125
# know  : meif -0.17338608
# know  : looking -0.055314716
# know  : solid -0.034122672
# know  : reliable 0.08668862
# know  : may -0.048369702
# know  : programmable -0.12110757
# know  : statistics 0.05793728
# know  : well 0.042434692
# know  : many -0.111422665
# know  : manual -0.07767054
# know  : makes -0.18480556
# know  : sense -0.08120125
# know  : running 0.024615793
# know  : short 0.15198654
# know  : orderim 0.2194485
# know  : ready -0.04492822
# know  : set 0.07837679
# know  : move -0.07173288
# know  : old 0.28473207
# know  : replace -0.0036183854
# know  : well 0.042434692
# know  : usehp -0.040479638
# many  : served -0.058730423
# many  : travelling 0.12898424
# many  : searched -0.12993215
# many  : one 0.05400606
# many  : replace 0.011062952
# many  : one 0.05400606
# many  : purchased 0.112574115
# many  : mistake 0.06417381
# many  : people 0.058057766
# many  : view -0.15117021
# many  : may -0.08422899
# many  : powerful -0.041052002
# many  : using 0.09134521
# many  : sketchy -0.010161559
# many  : need 0.1001844
# many  : way -0.11522259
# many  : sense 0.075307734
# many  : meif -0.012195898
# many  : solid 0.09269189
# many  : reliable 0.058628418
# many  : may -0.08422899
# many  : programmable 0.0037485517
# many  : statistics -0.022320101
# many  : well 0.10441836
# many  : sense 0.075307734
# many  : running 0.055135712
# many  : short -0.089209236
# many  : orderim -0.06841628
# many  : ready -0.07809581
# many  : set 0.04152547
# many  : move 0.19829662
# many  : old 0.07197939
# many  : replace 0.011062952
# many  : well 0.10441836
# many  : usehp -0.009540618
# people  : served 0.0077082473
# people  : travelling -0.19820222
# people  : searched 0.14184754
# people  : replace 0.06590117
# people  : purchased 0.077711865
# people  : view 0.13103665
# people  : powerful 0.013211999
# people  : using -0.06748942
# people  : sketchy -0.019585744
# people  : way -0.052398834
# people  : sense 0.00979689
# people  : solid -0.09030889
# people  : reliable 0.077042505
# people  : programmable 0.07532936
# people  : statistics -0.034246
# people  : well -0.003012478
# people  : sense 0.00979689
# people  : running 0.05632538
# people  : short 0.10628751
# people  : ready -0.021016551
# people  : set -0.02024723
# people  : replace 0.06590117
# people  : well -0.003012478
# people  : usehp -0.049727704
# view  : way 0.04206633
# view  : well -0.099614546
# view  : well -0.099614546
# hp  : hp12c -0.10700917
# hp  : served 0.07317559
# hp  : lost -0.11701512
# hp  : travelling -0.0076341215
# hp  : searched -0.23525049
# hp  : one 0.12941937
# hp  : replace 0.099550016
# hp  : one 0.12941937
# hp  : purchased 0.007682179
# hp  : mistake -0.17537518
# hp  : know 0.073518045
# hp  : many -0.111629225
# hp  : people -0.05704288
# hp  : view -0.0755801
# hp  : line -0.034542456
# hp  : may 0.14208616
# hp  : powerful 0.20568836
# hp  : using -0.1385196
# hp  : manual 0.10488667
# hp  : sketchy -0.021226026
# hp  : need -0.10472019
# hp  : way -0.10633773
# hp  : makes 0.024053058
# hp  : sense -0.05868675
# hp  : meif -0.025837913
# hp  : looking 0.023399206
# hp  : solid 0.04100031
# hp  : reliable -0.036193695
# hp  : hp12c -0.10700917
# hp  : may 0.14208616
# hp  : programmable 0.018359851
# hp  : statistics 0.02343352
# hp  : well -0.13377988
# hp  : many -0.111629225
# hp  : manual 0.10488667
# hp  : makes 0.024053058
# hp  : sense -0.05868675
# hp  : running -0.17155127
# hp  : short 0.18950808
# hp  : orderim 0.12484109
# hp  : ready 0.025622105
# hp  : set -0.1414194
# hp  : move 0.14051762
# hp  : old -0.06276717
# hp  : replace 0.099550016
# hp  : well -0.13377988
# hp  : usehp 0.09521609
# hp  : im -0.16079812
# 49g  : bought -0.06758465
# 49g  : first 0.1554061
# 49g  : hp12c 0.14062624
# 49g  : served 0.011759298
# 49g  : faithfully 0.112470165
# 49g  : lost -0.099636234
# 49g  : travelling 0.003085442
# 49g  : searched 0.22173272
# 49g  : another 0.105357796
# 49g  : one -0.00298943
# 49g  : replace -0.07149416
# 49g  : found 0.07393998
# 49g  : one -0.00298943
# 49g  : difficult -0.122904494
# 49g  : come -0.08041403
# 49g  : area -0.09192875
# 49g  : decided 0.047910288
# 49g  : buy 0.06760444
# 49g  : purchased -0.045623597
# 49g  : hp 0.0523196
# 49g  : mistake -0.032432113
# 49g  : know -0.052212544
# 49g  : many -0.06958547
# 49g  : people 0.02538858
# 49g  : view 0.27605247
# 49g  : hp 0.0523196
# 49g  : 49g+ -0.16550966
# 49g  : flagship -0.037511334
# 49g  : hp 0.0523196
# 49g  : line 0.08297605
# 49g  : disasterthe 0.07725054
# 49g  : may -0.1345508
# 49g  : powerful 0.0041445056
# 49g  : using -0.09805582
# 49g  : extremely 0.03303127
# 49g  : counterintuitiveand 0.09606037
# 49g  : manual 0.06729656
# 49g  : sketchy 0.17243613
# 49g  : best 0.030927125
# 49g  : hand 0.08194016
# 49g  : need 0.20940849
# 49g  : way -0.020776616
# 49g  : makes 0.06942752
# 49g  : good 0.06922048
# 49g  : sense -0.040475823
# 49g  : meif -0.197236
# 49g  : looking 0.0799404
# 49g  : solid -0.060759444
# 49g  : reliable -0.014168556
# 49g  : calculator -0.021669187
# 49g  : hp12c 0.14062624
# 49g  : may -0.1345508
# 49g  : programmable -0.0873708
# 49g  : basic 0.18767066
# 49g  : statistics -0.12864259
# 49g  : well -0.09057644
# 49g  : many -0.06958547
# 49g  : business -0.042117573
# 49g  : applications 0.16189748
# 49g  : manual 0.06729656
# 49g  : makes 0.06942752
# 49g  : sense -0.040475823
# 49g  : running 0.15550025
# 49g  : short 0.15824866
# 49g  : orderim 0.09146529
# 49g  : ready -0.11874571
# 49g  : set -0.025183557
# 49g  : aside 0.095975034
# 49g  : move -0.20131099
# 49g  : back -0.040228736
# 49g  : old 0.037803773
# 49g  : friend -0.15570347
# 49g  : didnt -0.0006688067
# 49g  : even 0.14021145
# 49g  : replace -0.07149416
# 49g  : batteries -0.013590398
# 49g  : well -0.09057644
# 49g  : decade 0.070473574
# 49g  : usehp 0.09178431
# 49g  : im 0.13673343
# 49g  : coming 0.0041993614
# 49g  : home -0.06397448
# 49g+  : bought 0.18889579
# 49g+  : first -0.06444266
# 49g+  : hp12c -0.12612869
# 49g+  : served 0.03586162
# 49g+  : faithfully 0.029503733
# 49g+  : lost -0.05184363
# 49g+  : travelling 0.1754389
# 49g+  : searched 0.19619288
# 49g+  : another -0.03755927
# 49g+  : one -0.11347135
# 49g+  : replace 0.04193938
# 49g+  : found -0.010745112
# 49g+  : one -0.11347135
# 49g+  : difficult -0.06856502
# 49g+  : come 0.14062735
# 49g+  : area -0.075551
# 49g+  : decided -0.08038172
# 49g+  : buy -0.060395774
# 49g+  : purchased -0.04087755
# 49g+  : hp 0.1214433
# 49g+  : mistake -0.090626016
# 49g+  : know -0.04165089
# 49g+  : many -0.073576
# 49g+  : people -0.0048708236
# 49g+  : view 0.060837373
# 49g+  : hp 0.1214433
# 49g+  : flagship -0.1035367
# 49g+  : hp 0.1214433
# 49g+  : line -0.0672191
# 49g+  : disasterthe -0.028186517
# 49g+  : may -0.049418394
# 49g+  : powerful 0.068599574
# 49g+  : using -0.025810128
# 49g+  : extremely 0.025270315
# 49g+  : counterintuitiveand 0.20311391
# 49g+  : manual -0.027412098
# 49g+  : sketchy -0.10877221
# 49g+  : best -0.16010244
# 49g+  : hand -0.14034803
# 49g+  : need -0.011731102
# 49g+  : way 0.0008823023
# 49g+  : makes -0.063998155
# 49g+  : good 0.025682984
# 49g+  : sense -0.25037995
# 49g+  : meif -0.054039326
# 49g+  : looking 0.03922215
# 49g+  : solid 0.1427478
# 49g+  : reliable 0.014196344
# 49g+  : calculator 0.07197615
# 49g+  : hp12c -0.12612869
# 49g+  : may -0.049418394
# 49g+  : programmable 0.10214763
# 49g+  : basic 0.14509034
# 49g+  : statistics -0.11004886
# 49g+  : well -0.18121758
# 49g+  : many -0.073576
# 49g+  : business -0.10428203
# 49g+  : applications 0.09249955
# 49g+  : manual -0.027412098
# 49g+  : makes -0.063998155
# 49g+  : sense -0.25037995
# 49g+  : running -0.20186149
# 49g+  : short 0.066665635
# 49g+  : orderim 0.13043456
# 49g+  : ready 0.10437651
# 49g+  : set -0.13967752
# 49g+  : aside -0.03033903
# 49g+  : move 0.009560039
# 49g+  : back -0.09121457
# 49g+  : old -0.12114692
# 49g+  : friend 0.009161751
# 49g+  : didnt -0.13059707
# 49g+  : even -0.100246474
# 49g+  : replace 0.04193938
# 49g+  : batteries 0.014691524
# 49g+  : well -0.18121758
# 49g+  : decade 0.14061746
# 49g+  : usehp -0.09356876
# 49g+  : im -0.16999198
# 49g+  : coming -0.02667242
# 49g+  : home -0.07314971
# flagship  : hp12c -0.09025415
# flagship  : served -0.053836506
# flagship  : lost -0.2210133
# flagship  : travelling -0.105230406
# flagship  : searched -0.09616433
# flagship  : one 0.04474678
# flagship  : replace -0.0321911
# flagship  : found 0.0351082
# flagship  : one 0.04474678
# flagship  : purchased -0.0511547
# flagship  : hp 0.09697093
# flagship  : mistake 0.041302558
# flagship  : know 0.0974526
# flagship  : many 0.07856057
# flagship  : people 0.026903797
# flagship  : view 0.043109953
# flagship  : hp 0.09697093
# flagship  : hp 0.09697093
# flagship  : line -0.01952588
# flagship  : may -0.039817043
# flagship  : powerful -0.08787551
# flagship  : using -0.1686162
# flagship  : manual -0.0951066
# flagship  : sketchy -0.041228097
# flagship  : hand -0.018725172
# flagship  : need -0.2858495
# flagship  : way -0.1758338
# flagship  : makes -0.03088149
# flagship  : good -0.1049905
# flagship  : sense 0.11860942
# flagship  : meif -0.12188876
# flagship  : looking 0.021006493
# flagship  : solid -0.14223713
# flagship  : reliable 0.014420728
# flagship  : hp12c -0.09025415
# flagship  : may -0.039817043
# flagship  : programmable -0.17603473
# flagship  : statistics 0.00063562614
# flagship  : well -0.017135039
# flagship  : many 0.07856057
# flagship  : manual -0.0951066
# flagship  : makes -0.03088149
# flagship  : sense 0.11860942
# flagship  : running 0.10946484
# flagship  : short 0.06626188
# flagship  : orderim 0.13931838
# flagship  : ready -0.10949945
# flagship  : set 0.13331369
# flagship  : move -0.063367575
# flagship  : old -0.014083492
# flagship  : friend 0.004526675
# flagship  : replace -0.0321911
# flagship  : well -0.017135039
# flagship  : usehp 0.0065719564
# flagship  : im -0.03427771
# flagship  : home -0.026883058
# hp  : hp12c -0.10700917
# hp  : served 0.07317559
# hp  : lost -0.11701512
# hp  : travelling -0.0076341215
# hp  : searched -0.23525049
# hp  : one 0.12941937
# hp  : replace 0.099550016
# hp  : one 0.12941937
# hp  : purchased 0.007682179
# hp  : mistake -0.17537518
# hp  : know 0.073518045
# hp  : many -0.111629225
# hp  : people -0.05704288
# hp  : view -0.0755801
# hp  : line -0.034542456
# hp  : may 0.14208616
# hp  : powerful 0.20568836
# hp  : using -0.1385196
# hp  : manual 0.10488667
# hp  : sketchy -0.021226026
# hp  : need -0.10472019
# hp  : way -0.10633773
# hp  : makes 0.024053058
# hp  : sense -0.05868675
# hp  : meif -0.025837913
# hp  : looking 0.023399206
# hp  : solid 0.04100031
# hp  : reliable -0.036193695
# hp  : hp12c -0.10700917
# hp  : may 0.14208616
# hp  : programmable 0.018359851
# hp  : statistics 0.02343352
# hp  : well -0.13377988
# hp  : many -0.111629225
# hp  : manual 0.10488667
# hp  : makes 0.024053058
# hp  : sense -0.05868675
# hp  : running -0.17155127
# hp  : short 0.18950808
# hp  : orderim 0.12484109
# hp  : ready 0.025622105
# hp  : set -0.1414194
# hp  : move 0.14051762
# hp  : old -0.06276717
# hp  : replace 0.099550016
# hp  : well -0.13377988
# hp  : usehp 0.09521609
# hp  : im -0.16079812
# line  : served -0.11729913
# line  : lost -0.06142698
# line  : travelling 0.07518312
# line  : searched 0.14805894
# line  : one 0.06265966
# line  : replace -0.036604043
# line  : one 0.06265966
# line  : purchased -0.1398466
# line  : mistake 0.036577143
# line  : many 0.023330152
# line  : people -0.08832721
# line  : view 0.03558784
# line  : may 0.016347837
# line  : powerful 0.03447155
# line  : using -0.013698719
# line  : manual -0.09907119
# line  : sketchy 0.05812709
# line  : need 0.11730653
# line  : way 0.1736979
# line  : makes -0.026434971
# line  : sense -0.07574773
# line  : meif -0.019101676
# line  : looking 0.018096352
# line  : solid 0.03793382
# line  : reliable 0.10748522
# line  : may 0.016347837
# line  : programmable 0.022934647
# line  : statistics 0.1279937
# line  : well -0.13593099
# line  : many 0.023330152
# line  : manual -0.09907119
# line  : makes -0.026434971
# line  : sense -0.07574773
# line  : running 0.06916466
# line  : short 0.2601268
# line  : orderim -0.007500012
# line  : ready -0.07657413
# line  : set -0.01019185
# line  : move 0.15592852
# line  : old -0.04260192
# line  : replace -0.036604043
# line  : well -0.13593099
# line  : usehp -0.0026605483
# disasterthe  : first -0.0065701827
# disasterthe  : hp12c 0.15260838
# disasterthe  : served -0.011675148
# disasterthe  : faithfully 0.1052466
# disasterthe  : lost -0.121453814
# disasterthe  : travelling -0.069256306
# disasterthe  : searched -0.0063362415
# disasterthe  : one 0.02271324
# disasterthe  : replace 0.01903548
# disasterthe  : found 0.14294754
# disasterthe  : one 0.02271324
# disasterthe  : purchased 0.0076775253
# disasterthe  : hp 0.12327609
# disasterthe  : mistake 0.04107261
# disasterthe  : know -0.1681069
# disasterthe  : many -0.13214844
# disasterthe  : people -0.14923304
# disasterthe  : view -0.05942688
# disasterthe  : hp 0.12327609
# disasterthe  : flagship -0.03254194
# disasterthe  : hp 0.12327609
# disasterthe  : line 0.043925434
# disasterthe  : may 0.02520744
# disasterthe  : powerful -0.016131729
# disasterthe  : using -0.13862333
# disasterthe  : extremely -0.028160498
# disasterthe  : manual 0.04152836
# disasterthe  : sketchy -0.17292087
# disasterthe  : hand 0.1448685
# disasterthe  : need -0.08322784
# disasterthe  : way 0.09674389
# disasterthe  : makes 0.0697854
# disasterthe  : good 0.077779554
# disasterthe  : sense -0.04339675
# disasterthe  : meif 0.15203188
# disasterthe  : looking 0.025936801
# disasterthe  : solid -0.11027598
# disasterthe  : reliable 0.00051304087
# disasterthe  : hp12c 0.15260838
# disasterthe  : may 0.02520744
# disasterthe  : programmable -0.12110825
# disasterthe  : statistics -0.1362311
# disasterthe  : well -0.149284
# disasterthe  : many -0.13214844
# disasterthe  : manual 0.04152836
# disasterthe  : makes 0.0697854
# disasterthe  : sense -0.04339675
# disasterthe  : running -0.04778184
# disasterthe  : short -0.20625253
# disasterthe  : orderim -0.042444993
# disasterthe  : ready -0.045366414
# disasterthe  : set 0.008360013
# disasterthe  : move 0.02454067
# disasterthe  : old 0.04565299
# ...
# friend  : purchased 0.049780674
# friend  : hp -0.008589858
# friend  : mistake -0.15802069
# friend  : know 0.12154561
# friend  : many -0.0056787916
# friend  : people 0.027690234
# friend  : view -0.028162155
# friend  : hp -0.008589858
# friend  : hp -0.008589858
# friend  : line -0.2836355
# friend  : may 0.07592174
# friend  : powerful -0.04176805
# friend  : using 0.14722471
# friend  : manual 0.06431731
# friend  : sketchy 0.16687381
# friend  : hand -0.038811
# friend  : need -0.10196127
# friend  : way 0.0048248554
# friend  : makes -0.1177685
# friend  : good -0.21637605
# friend  : sense -0.021973696
# friend  : meif 0.12658316
# friend  : looking -0.06385866
# friend  : solid 0.020068906
# friend  : reliable -0.14183052
# friend  : hp12c -0.05295573
# friend  : may 0.07592174
# friend  : programmable -0.07856576
# friend  : statistics 0.0006103993
# friend  : well 0.20463432
# friend  : many -0.0056787916
# friend  : manual 0.06431731
# friend  : makes -0.1177685
# friend  : sense -0.021973696
# friend  : running 0.013117686
# friend  : short -0.13200949
# friend  : orderim -0.15107147
# friend  : ready -0.010350628
# friend  : set 0.072669655
# friend  : move 0.009726278
# friend  : old 0.0503299
# friend  : replace -0.21566516
# friend  : well 0.20463432
# friend  : usehp -0.0008267086
# friend  : im -0.013153691
# friend  : home 0.13703036
# didnt  : first -0.09544179
# didnt  : hp12c -0.17227793
# didnt  : served -0.27876195
# didnt  : faithfully -0.089687094
# didnt  : lost 0.07539717
# didnt  : travelling -0.34984788
# didnt  : searched -0.09611429
# didnt  : one 0.044882912
# didnt  : replace -0.018036334
# didnt  : found -0.13482325
# didnt  : one 0.044882912
# didnt  : difficult -0.019525366
# didnt  : purchased -0.10050044
# didnt  : hp -0.06493768
# didnt  : mistake -0.08920518
# didnt  : know -0.15804239
# didnt  : many 0.049260724
# didnt  : people -0.05429162
# didnt  : view -0.09192522
# didnt  : hp -0.06493768
# didnt  : flagship -0.043104462
# didnt  : hp -0.06493768
# didnt  : line 0.010883242
# didnt  : disasterthe -0.006480874
# didnt  : may 0.01463502
# didnt  : powerful 0.014275983
# didnt  : using -0.06716035
# didnt  : extremely -0.00016173953
# didnt  : manual -0.016037548
# didnt  : sketchy 0.14274259
# didnt  : hand 0.028331988
# didnt  : need 0.07434194
# didnt  : way 0.0032226352
# didnt  : makes 0.09586425
# didnt  : good -0.15079348
# didnt  : sense 0.0359883
# didnt  : meif -0.0053762943
# didnt  : looking -0.0046512233
# didnt  : solid 0.00024052174
# didnt  : reliable 0.07974279
# didnt  : hp12c -0.17227793
# didnt  : may 0.01463502
# didnt  : programmable 0.109969795
# didnt  : statistics -0.045982867
# didnt  : well 0.24855219
# didnt  : many 0.049260724
# didnt  : manual -0.016037548
# didnt  : makes 0.09586425
# didnt  : sense 0.0359883
# didnt  : running -0.09925161
# didnt  : short 0.06428184
# didnt  : orderim -0.046276256
# didnt  : ready -0.20015249
# didnt  : set -0.14130822
# didnt  : move 0.202482
# didnt  : old 0.00785959
# didnt  : friend -0.005192538
# didnt  : even 0.05261253
# didnt  : replace -0.018036334
# didnt  : well 0.24855219
# didnt  : usehp 0.15958641
# didnt  : im -0.0033248938
# didnt  : home -0.10471282
# even  : first -0.048385084
# even  : hp12c 0.08582375
# even  : served 0.0486739
# even  : faithfully 0.07386351
# even  : lost 0.019594785
# even  : travelling 0.04098841
# even  : searched -0.07629143
# even  : one 0.11112033
# even  : replace 0.016228808
# even  : found -0.039457515
# even  : one 0.11112033
# even  : purchased 0.06332444
# even  : hp 0.021346044
# even  : mistake 0.104702815
# even  : know 0.041965455
# even  : many -0.08087016
# even  : people -0.09090415
# even  : view -0.0547464
# even  : hp 0.021346044
# even  : flagship -0.13886172
# even  : hp 0.021346044
# even  : line 0.014986629
# even  : may -0.13705747
# even  : powerful 0.020048715
# even  : using -0.11459134
# even  : extremely -0.08455558
# even  : manual 0.07922687
# even  : sketchy 0.17374896
# even  : hand 0.08526663
# even  : need 0.008321294
# even  : way -0.03346421
# even  : makes -0.029437497
# even  : good 0.059324335
# even  : sense -0.11088163
# even  : meif 0.12449193
# even  : looking -0.05214612
# even  : solid -0.1586366
# even  : reliable 0.03907961
# even  : hp12c 0.08582375
# even  : may -0.13705747
# even  : programmable -0.06866407
# even  : statistics -0.04440423
# even  : well 0.27485758
# even  : many -0.08087016
# even  : manual 0.07922687
# even  : makes -0.029437497
# even  : sense -0.11088163
# even  : running 0.14702077
# even  : short -0.043804783
# even  : orderim 0.071730256
# even  : ready -0.021984892
# even  : set 0.11672903
# even  : move -0.014134472
# even  : old -0.04086233
# even  : friend -0.17764142
# even  : replace 0.016228808
# even  : well 0.27485758
# even  : usehp 0.033042703
# even  : im -0.06051784
# even  : home -0.09975705
# replace  : served -0.0136855515
# replace  : travelling 0.21775621
# replace  : searched 0.055327628
# replace  : view -0.0894385
# replace  : using 0.09662213
# replace  : sketchy -0.0628247
# replace  : way -0.20368303
# replace  : sense -0.090631604
# replace  : solid 0.17549258
# replace  : statistics 0.16097426
# replace  : well 0.053403795
# replace  : sense -0.090631604
# replace  : running -0.11655331
# replace  : short 0.071116224
# replace  : set 0.053629965
# replace  : well 0.053403795
# replace  : usehp 0.20741606
# batteries  : bought 0.02519478
# batteries  : first 0.23400265
# batteries  : hp12c -0.021785384
# batteries  : served 0.19586934
# batteries  : faithfully 0.10520935
# batteries  : lost -0.0747258
# batteries  : travelling -0.049058955
# batteries  : searched 0.14313368
# batteries  : one 0.013013485
# batteries  : replace -0.05215399
# batteries  : found 0.18794852
# batteries  : one 0.013013485
# batteries  : difficult 0.016977342
# batteries  : come -0.03576133
# batteries  : decided -0.11824446
# batteries  : buy -0.052111797
# batteries  : purchased 0.15248202
# batteries  : hp 0.059920166
# batteries  : mistake 0.15757462
# batteries  : know 0.083795756
# batteries  : many 0.09039844
# batteries  : people 0.011273024
# batteries  : view 0.06353722
# batteries  : hp 0.059920166
# batteries  : flagship 0.08598474
# batteries  : hp 0.059920166
# batteries  : line -0.18311892
# batteries  : disasterthe 0.15976796
# batteries  : may -0.13180716
# batteries  : powerful 0.026719542
# batteries  : using 0.13409893
# batteries  : extremely -0.11353142
# batteries  : counterintuitiveand 0.0019147277
# batteries  : manual 0.12867893
# batteries  : sketchy -0.10637929
# batteries  : best 0.13169686
# batteries  : hand 0.005580456
# batteries  : need -0.012981293
# batteries  : way -0.0497941
# batteries  : makes 0.116028644
# batteries  : good -0.04881478
# batteries  : sense -0.027619757
# batteries  : meif 0.110465296
# batteries  : looking -0.03699183
# batteries  : solid 0.15074088
# batteries  : reliable 0.037028216
# batteries  : calculator -0.17092897
# batteries  : hp12c -0.021785384
# batteries  : may -0.13180716
# batteries  : programmable 0.04101765
# batteries  : statistics 0.029020868
# batteries  : well -0.07594515
# batteries  : many 0.09039844
# batteries  : business 0.18432397
# batteries  : manual 0.12867893
# batteries  : makes 0.116028644
# batteries  : sense -0.027619757
# batteries  : running -0.057658978
# batteries  : short -0.20143865
# batteries  : orderim 0.07488444
# batteries  : ready 0.03511543
# batteries  : set 0.26656953
# batteries  : move 0.024810148
# batteries  : old 0.07448825
# batteries  : friend 0.11384226
# batteries  : didnt -0.25546646
# batteries  : even -0.011001767
# batteries  : replace -0.05215399
# batteries  : well -0.07594515
# batteries  : decade -0.0020065745
# batteries  : usehp -0.03904405
# batteries  : im -0.0004295173
# batteries  : coming -0.046233617
# batteries  : home 0.151704
# decade  : first -0.12532721
# decade  : hp12c -0.0796902
# decade  : served 0.07401187
# decade  : faithfully 0.051956456
# decade  : lost 0.08929367
# decade  : travelling 0.15245958
# decade  : searched 0.093270086
# decade  : one 0.07264408
# decade  : replace 0.040897064
# decade  : found 0.06869801
# decade  : one 0.07264408
# decade  : difficult -0.04761099
# decade  : decided -0.11482265
# decade  : purchased 0.19906019
# decade  : hp 0.090352945
# decade  : mistake -0.13214302
# decade  : know 0.12824567
# decade  : many 0.076464884
# decade  : people 0.05798313
# decade  : view -0.0544575
# decade  : hp 0.090352945
# decade  : flagship -0.118608914
# decade  : hp 0.090352945
# decade  : line -0.006210476
# decade  : disasterthe 0.12805244
# decade  : may -0.05079086
# decade  : powerful -0.07787437
# decade  : using 0.06076884
# decade  : extremely 0.06449252
# decade  : manual 0.06312077
# decade  : sketchy 0.059886005
# decade  : hand 0.029120628
# decade  : need 0.0033579727
# decade  : way 0.06842688
# decade  : makes -0.23290081
# decade  : good 0.07214878
# decade  : sense -0.036951687
# decade  : meif -0.07441309
# decade  : looking 0.034546386
# decade  : solid 0.033413604
# decade  : reliable -0.03617746
# decade  : hp12c -0.0796902
# decade  : may -0.05079086
# decade  : programmable 0.0006406071
# decade  : statistics -0.090098865
# decade  : well 0.034533482
# decade  : many 0.076464884
# decade  : manual 0.06312077
# decade  : makes -0.23290081
# decade  : sense -0.036951687
# decade  : running -8.138176e-05
# decade  : short 0.22435533
# decade  : orderim -0.13279836
# decade  : ready -0.009588722
# decade  : set 0.062364597
# decade  : move 0.041537866
# decade  : old 0.041140415
# decade  : friend -0.02778884
# decade  : didnt -0.08832997
# decade  : even 0.20171294
# decade  : replace 0.040897064
# decade  : well 0.034533482
# decade  : usehp 0.0059691835
# decade  : im 0.113000214
# decade  : home 0.049455438
# usehp  : view -0.009823178
# usehp  : using -0.11290144
# usehp  : way 0.06238935
# usehp  : well 0.20156273
# usehp  : well 0.20156273
# 12c  : bought 0.09752824
# 12c  : first -0.10982317
# 12c  : hp12c -0.00064526766
# 12c  : 1984 -0.049844366
# 12c  : served 0.039328933
# 12c  : faithfully 0.008741814
# 12c  : 2002 -0.025520323
# 12c  : lost -0.16386215
# 12c  : travelling 0.018381855
# 12c  : searched 0.2041558
# 12c  : another -0.03498694
# 12c  : one -0.075720154
# 12c  : replace -0.12469338
# 12c  : found -0.022270435
# 12c  : one -0.075720154
# 12c  : difficult -0.017643595
# 12c  : come -0.058942925
# 12c  : area -0.23524885
# 12c  : decided -0.07231976
# 12c  : buy 0.04011339
# 12c  : purchased 0.07182519
# 12c  : hp -0.03659711
# 12c  : 49g -0.0751731
# 12c  : mistake -0.0967091
# 12c  : know 0.0727261
# 12c  : many 0.06880141
# 12c  : people 0.032088377
# 12c  : view -0.03698211
# 12c  : hp -0.03659711
# 12c  : 49g -0.0751731
# 12c  : 49g+ 0.037450664
# 12c  : flagship 0.035656743
# 12c  : hp -0.03659711
# 12c  : line 0.01912056
# 12c  : disasterthe 0.03910216
# 12c  : 49g -0.0751731
# 12c  : may 0.04577732
# 12c  : powerful -0.14200963
# 12c  : using 0.13782714
# 12c  : extremely -0.16367207
# 12c  : counterintuitiveand 0.023560796
# 12c  : manual -0.06037067
# 12c  : sketchy -0.17536604
# 12c  : best -0.057764273
# 12c  : hand -0.008986875
# 12c  : need -0.13006648
# 12c  : way -0.010210007
# 12c  : makes -0.09027892
# 12c  : good -0.11743344
# 12c  : sense 0.0033968086
# 12c  : meif -0.11692873
# 12c  : looking 0.004374781
# 12c  : solid 0.109827034
# 12c  : reliable 0.055987604
# 12c  : calculator 0.05080955
# 12c  : hp12c -0.00064526766
# 12c  : may 0.04577732
# 12c  : programmable 0.1361101
# 12c  : basic 0.21816245
# 12c  : statistics 0.102605425
# 12c  : well -0.15833983
# 12c  : many 0.06880141
# 12c  : business -0.053625636
# 12c  : applications -0.19088295
# 12c  : manual -0.06037067
# 12c  : makes -0.09027892
# 12c  : sense 0.0033968086
# 12c  : running -0.002996569
# 12c  : short 0.06642766
# 12c  : orderim -0.049825035
# 12c  : ready 0.064147286
# 12c  : set -0.07342744
# 12c  : 49g -0.0751731
# 12c  : aside -0.04454907
# 12c  : move -0.0062536234
# 12c  : back -0.0037145303
# 12c  : old -0.040770873
# 12c  : friend 0.030875187
# 12c  : didnt -0.11164479
# 12c  : even -0.051920947
# 12c  : replace -0.12469338
# 12c  : batteries 0.13809228
# 12c  : well -0.15833983
# 12c  : decade 0.05800975
# 12c  : usehp -0.20397492
# 12c  : im 0.09969357
# 12c  : coming 0.05948463
# 12c  : home 0.06901015
# im  : served 0.017580565
# im  : lost 0.024389073
# im  : travelling -0.0044733556
# im  : searched 0.056746624
# im  : one -0.0795196
# im  : replace -0.10814978
# im  : one -0.0795196
# im  : purchased 0.029522922
# im  : mistake -0.15802388
# im  : know -0.020334117
# im  : many 0.013195968
# im  : people -0.014488976
# im  : view -0.11009176
# im  : line -0.020368949
# im  : may -0.09845274
# im  : powerful -0.03883308
# im  : using 0.12250707
# im  : manual -0.04400655
# im  : sketchy -0.05257414
# im  : need 0.03191663
# im  : way 0.06911949
# im  : makes -0.024038747
# im  : sense 0.030855892
# im  : meif 0.02727617
# im  : looking -0.19034474
# im  : solid -0.041928023
# im  : reliable -0.14609757
# im  : may -0.09845274
# im  : programmable -0.08746959
# im  : statistics -0.05388769
# im  : well -0.021497963
# im  : many 0.013195968
# im  : manual -0.04400655
# im  : makes -0.024038747
# im  : sense 0.030855892
# im  : running 0.07598468
# im  : short -0.15342571
# im  : orderim -0.06918021
# im  : ready -0.02804478
# im  : set 0.066716366
# im  : move -0.018041817
# im  : old 0.13554253
# im  : replace -0.10814978
# im  : well -0.021497963
# im  : usehp -0.12975019
# coming  : first 0.2803238
# coming  : hp12c 0.031933144
# coming  : served -0.15216586
# coming  : faithfully 0.050666437
# coming  : lost -0.00021170737
# coming  : travelling 0.025850425
# coming  : searched 0.062224578
# coming  : one -0.056509867
# coming  : replace -0.2139951
# coming  : found 0.057349186
# coming  : one -0.056509867
# coming  : difficult -0.09878482
# coming  : decided -0.033609718
# coming  : purchased 0.27530912
# coming  : hp -0.10467748
# coming  : mistake -0.08704341
# coming  : know 0.065151595
# coming  : many 0.20741062
# coming  : people -0.037514735
# coming  : view 0.016656911
# coming  : hp -0.10467748
# coming  : flagship -0.03919614
# coming  : hp -0.10467748
# coming  : line 0.21325931
# coming  : disasterthe 0.049178414
# coming  : may -0.16612852
# coming  : powerful 0.016313089
# coming  : using -0.035123315
# coming  : extremely 0.1245452
# coming  : counterintuitiveand -0.08322979
# coming  : manual -0.102482565
# coming  : sketchy 0.08909961
# coming  : hand -0.11304279
# coming  : need 0.042042866
# coming  : way 0.03887094
# coming  : makes -0.063190475
# coming  : good -0.094380915
# coming  : sense -0.014939364
# coming  : meif 0.041187502
# coming  : looking -0.08185302
# coming  : solid -0.104739465
# coming  : reliable -0.032195244
# coming  : hp12c 0.031933144
# coming  : may -0.16612852
# coming  : programmable 0.05515189
# coming  : statistics 0.015861705
# coming  : well 0.12546621
# coming  : many 0.20741062
# coming  : manual -0.102482565
# coming  : makes -0.063190475
# coming  : sense -0.014939364
# coming  : running 0.0958728
# coming  : short -0.0014010663
# coming  : orderim -0.0037875476
# coming  : ready 0.13170452
# coming  : set 0.24283403
# coming  : move 0.15267542
# coming  : old 0.022089265
# coming  : friend -0.0466109
# coming  : didnt 0.0021574632
# coming  : even 0.23332773
# coming  : replace -0.2139951
# coming  : well 0.12546621
# coming  : decade 0.07743047
# coming  : usehp -0.15182178
# coming  : im 0.052701097
# coming  : home -0.027027959
# home  : hp12c -0.013518427
# home  : served -0.052694622
# home  : lost -0.20427209
# home  : travelling -0.04063827
# home  : searched -0.010853721
# home  : one 0.043697968
# home  : replace 0.15211168
# home  : one 0.043697968
# home  : purchased 0.110944346
# home  : hp 0.016419848
# home  : mistake 0.07577011
# home  : know 0.1477658
# home  : many 0.051778022
# home  : people 0.020621244
# home  : view -0.1178728
# home  : hp 0.016419848
# home  : hp 0.016419848
# home  : line -0.074320555
# home  : may 0.0691074
# home  : powerful -0.36169454
# home  : using 0.07031035
# home  : manual 0.11919315
# home  : sketchy 0.084980495
# home  : need 0.061803363
# home  : way 0.23487134
# home  : makes 0.11842616
# home  : sense -0.04567824
# home  : meif 0.054218795
# home  : looking -0.21369986
# home  : solid -0.23248853
# home  : reliable 0.04233449
# home  : hp12c -0.013518427
# home  : may 0.0691074
# home  : programmable -0.1263301
# home  : statistics -0.04093314
# home  : well -0.17751859
# home  : many 0.051778022
# home  : manual 0.11919315
# home  : makes 0.11842616
# home  : sense -0.04567824
# home  : running -0.0068308352
# home  : short -0.15248895
# home  : orderim -0.15625256
# home  : ready -0.11942394
# home  : set 0.14004795
# home  : move 0.07952765
# home  : old 0.12094465
# home  : replace 0.15211168
# home  : well -0.17751859
# home  : usehp -0.0048385034
# home  : im -0.044861645
